# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 2</b></center>
#     NAME       :- JENIL VEGAD
#     ENROLLMENT :- 24010101300
#     ROLL       :- 479
# <pre>

# %% [markdown]
# ### 01) WAP to print “Hello World..!!”

# %%
print('hello world')

# %% [markdown]
# ### 02) WAP to accept your name and display a welcome message.
# #### Input: Priya
# #### Output: Hello Priya, welcome to Python Lab.

# %%
name = input('eneter name')
print('hello ' + name + ', welcome to python lab')

# %% [markdown]
# ### 03) WAP to accept three integers and display the numbers, their sum, and average.
# #### Input: 10 20 30
# #### Output:
# ##### Numbers: 10 20 30
# ##### Sum: 60
# ##### Average: 20.0

# %%
a = float(input('enter a: '))
b = float(input('enter b: '))
c = float(input('enter c: '))
total = a + b + c
avg = total / 3
print(f'a: {a}  b: {b}  c: {c}')
print(total)
print(avg)

# %% [markdown]
# ### 04) WAP to accept name (string), age (int), and percentage (float).
# #### Input : Riya,18,92.5
# #### Output :
# ##### Name: Riya  Type: <class 'str'>
# ##### Age: 18  Type: <class 'int'>
# ##### Percentage: 92.5  Type: <class 'float'>

# %%
name = input('name')
age = int(input('age is : '))
per = float(input('persent :'))
print(f'name is {name} & {type(name)} age is {age} & {type(age)} paersent is {per} & {type(per)}')

# %% [markdown]
# ### 05) WAP to print folowing message using custom separator and end.
# #### Ouutput : Python | Programming | Basics###

# %%
print('Python', 'Programming', 'Basics', sep=' | ', end='###')

# %% [markdown]
# ### 06) WAP to accept a value and display its value, type, and memory id.
# #### Input : hello
# #### Output :
# ##### Value: hello
# ##### Type: <class 'str'>
# ##### ID: 140712345678912

# %%
greet = input('enter to greet :')
print('value: ', greet)
print('type: ', type(greet))
print('ID: ', id(greet))

# %% [markdown]
# ### 07) WAP to assign a value to a variable, print id, reassign a new value, and print id again.
# #### Output :
# ##### Original ID of a: 140712345678912
# ##### New ID of a: 140712345678960

# %%
A = 30
print('Original ID of a:', id(A))
A = 40
print('New ID of a:', id(A))

# %% [markdown]
# ### 08) WAP to print multiple lines using a single print().
# #### Output:
# ##### Welcome to Python
# ##### This is the second lab
# ##### Enjoy coding!

# %%
print('\nwelcome to python\nthis is the second lab\nenjoy coding!\n')

# %% [markdown]
# ### 09) WAP to display following table of items with proper alignment.
# #### Output :
# | Sr No | Name        | Subject | Grade | Percentage |
# | ----: | ----------- | ------- | :---: | ---------: |
# |     1 | Nisha Patel | Math    |   A   |         92 |
# |     2 | Aarav Modi  | Science |   B+  |         85 |
# |     3 | Jiya Shah   | English |   A+  |         96 |

# %%
print(' {:<6} {:<15} {:<12} {:<6} {:<10}'.format('Sr No', 'Name', 'Subject', 'Grade', 'Percentage'))
print(' {:<6} {:<15} {:<12} {:<6} {:<10}'.format(1, 'Nisha Patel', 'Math', 'A', 92))
print(' {:<6} {:<15} {:<12} {:<6} {:<10}'.format(2, 'Aarav Modi', 'Science', 'B+', 85))
print(' {:<6} {:<15} {:<12} {:<6} {:<10}'.format(3, 'Jiya Shah', 'English', 'A+', 96))

# %% [markdown]
# ### 10) WAP to accept a float number and display with 2 decimals, 3 decimals, and width 10.
# #### Input : 37.2567
# #### Output :
# ##### 2 decimals: 37.26
# ##### 3 decimals: 37.257
# ##### Width 10:      37.26

# %%
num = float(input('Enter a float number: '))
print('2 decimals :', format(num, '.2f'))
print('3 decimals :', format(num, '.3f'))
print('Width 10   :', format(num, '10.2f'))

# %% [markdown]
# ### 11) WAP to accept two integers and display sum, difference, and product using f-strings.
# #### Input : 12 8
# #### Output :
# ##### Sum = 20
# ##### Difference = 4
# ##### Product = 96

# %%
A, B = input('enter 2 num').split()
A = int(A)
B = int(B)
sum = A + B
dif = A - B
product = A * B
txt = f'SUM ={sum} DIFFERENCE ={dif} PRODUCT ={product}'
print(txt)

# %% [markdown]
# ### 12) WAP to accept date in dd mm yyyy format and display in multiple formats.
# #### Input : 01 12 2025
# #### Output :
# ##### 01/12/2025
# ##### 2025-12-01

# %%
dd, mm, yy = input('enter a date :').split()
print(dd, mm, yy, sep='/')
print(yy, mm, dd, sep='-')

# %% [markdown]
# ### 13) WAP to calculate area and perimeter of a circle.

# %%
import math
rad = float(input('enter a radius :'))
par = 2 * math.pi * rad
area = math.pi * rad * rad
print('parimeter : - ', par)
print('area : - ', area)

# %% [markdown]
# ### 14) WAP to convert degree into Fahrenheit and vice versa.

# %%
import math
deg = float(input('enter dig'))
fer = deg * 9 / 5 + 32
print(fer)

# %% [markdown]
# ### 15) WAP to get the distance from user into kilometer, and convert it into meter, feet, inches and centimeter.

# %%
km = float(input('Enter distance in kilometer: '))
meters = km * 1000
feet = meters * 3.28084
inches = meters * 39.3701
centimeters = meters * 100
print('Meters      :', meters)
print('Feet        :', feet)
print('Inches      :', inches)
print('Centimeters :', centimeters)
